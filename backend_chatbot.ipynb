# %%
# Instalar dependencias (biblitecas necessárias para rodar o código)

# !pip install python-telegram-bot
# !pip install langchain
# !pip install Chroma
# !pip install chromadb
# !pip install pypdf
# !pip install openai==0.28
# !pip install tiktoken
# !pip install deep-translator

# %%
# Criar a pasta "base_pdfs" na raiza da máquina virtual
# !mkdir -p /content/base_pdfs

# Download de todos os pdfs da pasta "base_pdfs" do GDrive
import gdown
url = "https://drive.google.com/drive/u/0/folders/15UftijLQkuHRmPHHkp8yuIkksIQxXkr-"
gdown.download_folder(url, quiet=True, use_cookies=False)

# Fazer download do arquivo "backend_chatbot.py" do GDrive
# !gdown --i 1ukhW-htY1c4gdu7SZ-NtqwaA_moDk_xN

# %%
# Executar o código principal

# !python main.py
# Out:
# --> Carregando arquivos PDF!
#
#
# --> Banco de dados criado com sucesso!
#
# /usr/local/lib/python3.10/dist-packages/langchain/llms/openai.py:243: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/langchain/llms/openai.py:1038: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(
#
# --> Modelo de recuperação conversacional criado com sucesso!
#
# Tokens Used: 3223
# 	Prompt Tokens: 3185
# 	Completion Tokens: 38
# Successful Requests: 1
# Total Cost (USD): $0.009707
#
# Tokens Used: 3633
# 	Prompt Tokens: 3518
# 	Completion Tokens: 115
# Successful Requests: 2
# Total Cost (USD): $0.011014000000000001
#
# Tokens Used: 2783
# 	Prompt Tokens: 2675
# 	Completion Tokens: 108
# ...
